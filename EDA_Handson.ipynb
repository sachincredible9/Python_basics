# %% [markdown]
# <a href="https://colab.research.google.com/github/sachincredible9/Python_basics/blob/main/EDA_Handson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Installing required packages

# %%
# !pip install numpy==2.0.2 pandas==2.2.2 matplotlib==3.10.0 seaborn==0.13.2 -q

# %% [markdown]
# #Import required packages

# %%
#library to help reading and manupalating data
import numpy as np
import pandas as pd

#Libraries to help with visualisation of data
import matplotlib.pyplot as plt
import seaborn as sns

#to restrict the float value to 3 decimal.
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
housing_data = pd.read_csv('Melbourne_Housing.csv')
housing_data.head()
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart  03-09-2016     3.300  3206.000
# 2   Albert Park      2    h        Thomson  03-09-2016     3.300  3206.000
# 3    Alphington      4    h          Brace  03-09-2016     6.400  3078.000
# 4    Alphington      3    h         Jellis  03-09-2016     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000          225   2016.000
# 1    2.000     1.000 0.000   120.000           82   1900.000
# 2    2.000     1.000 0.000   159.000          inf        NaN
# 3    3.000     2.000 4.000   853.000          263   1930.000
# 4    3.000     2.000 2.000   208.000          inf   2013.000
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# ...

# %%
housing_data.size
# Out:
# 433824

# %%
housing_data.ndim
# Out:
# 2

# %%
housing_data.tail()
# Out:
#                  Suburb  Rooms Type    SellerG        Date  Distance  \
# 27109        Noble Park      3    h        C21  30-09-2017    22.700
# 27110         Reservoir      3    u         RW  30-09-2017    12.000
# 27111     Roxburgh Park      4    h      Raine  30-09-2017    20.600
# 27112  Springvale South      3    h  Harcourts  30-09-2017    22.200
# 27113       Westmeadows      4    h      Barry  30-09-2017    16.500
#
#        Postcode  Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 27109  3174.000    3.000     1.000 6.000   569.000          130   1959.000
# 27110  3073.000    3.000     1.000 1.000       NaN          105   1990.000
# 27111  3064.000    4.000     2.000 2.000       NaN          225   1995.000
# 27112  3172.000    3.000     2.000 1.000   544.000          NaN        NaN
# 27113  3049.000    4.000     2.000 6.000   813.000          140   1960.000
#
#                        Regionname  Propertycount   Price
# ...

# %%
housing_data.shape
print("Rows = ",housing_data.shape[0])
print("Columns = ",housing_data.shape[1])
# Out:
# Rows =  27114
# Columns =  16

# %%
housing_data.head(10)
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart  03-09-2016     3.300  3206.000
# 2   Albert Park      2    h        Thomson  03-09-2016     3.300  3206.000
# 3    Alphington      4    h          Brace  03-09-2016     6.400  3078.000
# 4    Alphington      3    h         Jellis  03-09-2016     6.400  3078.000
# 5        Altona      3    h           Greg  03-09-2016    13.800  3018.000
# 6  Altona North      5    h             FN  03-09-2016    11.100  3025.000
# 7  Altona North      3    h            Jas  03-09-2016    11.100  3025.000
# 8  Altona North      4    h  hockingstuart  03-09-2016    11.100  3025.000
# 9      Armadale      2    u         Jellis  03-09-2016     6.300  3143.000
#
#    Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000          225   2016.000
# ...

# %%
for col in housing_data.columns:
  print(col)
housing_data.columns.size
# Out:
# Suburb
# Rooms
# Type
# SellerG
# Date
# Distance
# Postcode
# Bedroom
# Bathroom
# Car
# Landsize
# BuildingArea
# YearBuilt
# Regionname
# Propertycount
# Price
# 16

# %%
housing_data.describe()
# Out:
#           Rooms  Distance  Postcode   Bedroom  Bathroom       Car  Landsize  \
# count 27114.000 27113.000 27113.000 20678.000 20672.000 20297.000 17873.000
# mean      2.992    11.279  3113.783     3.046     1.592     1.716   560.537
# std       0.955     6.784   111.114     0.955     0.701     0.994  1411.309
# min       1.000     0.000  3000.000     0.000     0.000     0.000    50.000
# 25%       2.000     6.400  3046.000     2.000     1.000     1.000   220.000
# 50%       3.000    10.500  3088.000     3.000     1.000     2.000   513.000
# 75%       4.000    14.000  3153.000     4.000     2.000     2.000   664.000
# max      16.000    48.100  3978.000    20.000     9.000    18.000 76000.000
#
#        YearBuilt  Propertycount        Price
# count  11985.000      27114.000    27114.000
# mean    1966.618       7564.205  1050563.546
# std       36.042       4493.596   641578.487
# min     1850.000         83.000    85000.000
# 25%     1950.000       4294.000   635000.000
# ...

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 3.3+ MB

# %%
housing_data['Suburb'].nunique()
# Out:
# 345

# %%
housing_data['Date'] = pd.to_datetime(housing_data['Date'], format='%d-%m-%Y')

# %%
housing_data['Date'].apply(type).value_counts()
# Out:
# Date
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>    27114
# Name: count, dtype: int64

# %%
unique_string_values = housing_data['BuildingArea'][housing_data['BuildingArea'].apply(lambda x: isinstance(x, str))].unique()
filtered_values = [value for value in unique_string_values if value in ['missing', 'inf', 'unknown']]
print(filtered_values)
# Out:
# ['inf', 'missing']

# %%
housing_data['BuildingArea'].unique()
# Out:
# array(['225', '82', 'inf', '263', '242', '251', '117', 'missing', '76',
#        '399', '118', '103', '180', '123', '218', '129', '167', '154',
#        '275', '121', nan, '125', '255', '75', '156', '240', '268', '108',
#        '69', '140', '214', '253', '189', '215', '96', '104', '100', '313',
#        '144', '93', '110', '70', '122', '51', '147', '113', '83', '56',
#        '137', '85', '64', '175', '3558', '170', '265', '353', '138', '19',
#        '116', '87', '74', '320', '300', '210', '120', '86', '97', '200',
#        '106', '14', '161', '128', '185', '146', '133', '115', '143',
#        '150', '195', '236', '276', '188', '179', '249', '141', '34', '73',
#        '107', '84', '81', '207', '50', '264', '312', '235', '221', '183',
#        '132', '160', '186', '78', '105', '145', '62', '220', '315', '181',
#        '61', '112', '420', '226', '266', '410', '449', '356', '477',
#        '250', '95', '190', '284', '247', '213', '209', '119', '111',
# ...

# %%
housing_data['BuildingArea'].apply(type).value_counts()
# Out:
# BuildingArea
# <class 'float'>    16571
# <class 'str'>      10543
# Name: count, dtype: int64

# %%
housing_data['BuildingArea'] = housing_data['BuildingArea'].replace(['inf','missing'],np.nan)

# %%
housing_data['BuildingArea'] =housing_data['BuildingArea'].astype(float)

# %%
housing_data['BuildingArea'].apply(type).value_counts()
# Out:
# BuildingArea
# <class 'float'>    27114
# Name: count, dtype: int64

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
housing_data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           6436
# Bathroom          6442
# Car               6817
# Landsize          9241
# BuildingArea     16585
# YearBuilt        15129
# Regionname           0
# Propertycount        0
# Price                0
# dtype: int64

# %%
housing_data.duplicated().sum()
# Out:
# np.int64(11)

# %%
housing_data.drop_duplicates(inplace=True)

# %%
housing_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
housing_data.describe().T
# Out:
#                   count                           mean                  min  \
# Rooms         27103.000                          2.992                1.000
# Date              27103  2017-05-23 12:25:09.441759488  2016-01-28 00:00:00
# Distance      27102.000                         11.280                0.000
# Postcode      27102.000                       3113.787             3000.000
# Bedroom       20678.000                          3.046                0.000
# Bathroom      20672.000                          1.592                0.000
# Car           20297.000                          1.716                0.000
# Landsize      17873.000                        560.537               50.000
# BuildingArea  10529.000                        154.512               11.000
# YearBuilt     11985.000                       1966.618             1850.000
# Propertycount 27103.000                       7564.741               83.000
# ...

# %%
sns.histplot(data=housing_data,color='green', bins=100,x='Price', binwidth=100000 , kde=True);
# plt.xlim(20000,30000)
plt.xlabel('Price of Cars')
plt.ylabel('Total Number of Cars')
plt.title('Distribution of Price of Cars')
# plt.boxplot(housing_data['Price'])
plt.show()

# plt.xlim(3000,2000)
# plt.ylim(0,100)

# %%
sns.histplot(housing_data['Rooms'])
# Out:
# <Axes: xlabel='Rooms', ylabel='Count'>

# %%
sns.histplot(data=housing_data,x='Price', binwidth=1000000,  hue='Type', kde=True);
plt.xlabel('Price of House')
plt.ylabel('Total Number of House')
plt.title('Distribution of Price of House')
#
# Out:
# Text(0.5, 1.0, 'Distribution of Price of House')

# %%
g= sns.FacetGrid(housing_data , col='Type');
sns.kdeplot(housing_data['Price'], fill=True);
g.map(sns.histplot,'Price');

# %%
sns.boxenplot(housing_data,x='Price', color='Green');
# plt.xlim(1,15)
sns.axes_style('whitegrid');

# %%
plt.figure(figsize=(10,10))
sns.boxplot(housing_data, x='Type', y='Price', hue='Type');

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate 1000 random data points from a normal distribution
data = np.random.randn(1000)

plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram with Matplotlib')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def plot_optimized_histogram(data, column_name):
    """
    Automatically calculates the optimal number of bins using the
    Freedman-Diaconis rule and plots the distribution.
    """
    series = data[column_name].dropna()

    # Calculate IQR (Interquartile Range)
    q25, q75 = np.percentile(series, [25, 75])
    iqr = q75 - q25

    # Calculate bin width: 2 * IQR * n^(-1/3)
    bin_width = 2 * iqr / (len(series) ** (1/3))

    # Calculate number of bins
    if bin_width > 0:
        nbins = int((series.max() - series.min()) / bin_width)
    else:
        nbins = 10 # Fallback

    print(f"Optimal bins detected: {nbins}")

    # Plotting
    plt.figure(figsize=(10, 6))
    sns.histplot(series, bins=nbins, kde=True, color='teal', edgecolor='white')
    plt.title(f'Optimized Histogram: {column_name} (Bins={nbins})')
    plt.xlabel(column_name)
    plt.ylabel('Frequency')
    plt.show()

# Usage Example:
plot_optimized_histogram(housing_data, 'Rooms')
# Out:
# Optimal bins detected: 112

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Sample Data: Customer spending in three different regions
np.random.seed(42)
data_region_a = np.random.normal(loc=50, scale=10, size=100)
data_region_b = np.random.normal(loc=60, scale=15, size=100)
data_region_c = np.random.normal(loc=45, scale=5, size=100)

# Introduce some outliers
data_region_a = np.append(data_region_a, [10, 100, 105])
data_region_b = np.append(data_region_b, [120, 125, 5])

# Combine into a DataFrame for easier plotting with Seaborn/Pandas
df = pd.DataFrame({
    'Spending': np.concatenate([data_region_a, data_region_b, data_region_c]),
    'Region': ['A']*len(data_region_a) + ['B']*len(data_region_b) + ['C']*len(data_region_c)
})

# Basic Box Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='Spending', data=df, palette='viridis');
plt.title('Customer Spending Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Spending ($)')
plt.show();
# Out:
# /tmp/ipython-input-3824120425.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='Spending', data=df, palette='viridis');

# %%
plt.figure(figsize=(8, 5))
plt.boxplot([data_region_a, data_region_b, data_region_c],
            labels=['Region A', 'Region B', 'Region C'],
            patch_artist=True, # Fills the box with color
            medianprops={'color': 'red', 'linewidth': 2},
            boxprops={'facecolor': 'lightgreen', 'edgecolor': 'darkgreen'},
            whiskerprops={'color': 'blue'},
            capprops={'color': 'black'})
plt.title('Matplotlib Box Plot with Custom Styles')
plt.ylabel('Spending ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipython-input-3986910496.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data_region_a, data_region_b, data_region_c],

# %%
# Create a melted DataFrame for pandas boxplot
df_melted = df.melt(id_vars=['Region'], var_name='Metric', value_name='Value')

plt.figure(figsize=(8, 5))
df.boxplot(column='Spending', by='Region', grid=False, rot=45, figsize=(8,5))
plt.title('Pandas Box Plot (Spending by Region)')
plt.suptitle('') # Suppress default pandas title
plt.ylabel('Spending ($)')
plt.xlabel('Region')
plt.show()

# %%
# The plot from the beginning of the article
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='Spending', data=df, palette='cubehelix')
plt.title('Customer Spending Distribution by Region (Seaborn)')
plt.xlabel('Region')
plt.ylabel('Spending ($)')
plt.show()
# Out:
# /tmp/ipython-input-1101094211.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='Spending', data=df, palette='cubehelix')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='Spending', data=df, palette='GnBu_r')
sns.stripplot(x='Region', y='Spending', data=df, color='black', size=4, jitter=0.2)
plt.title('Box Plot with Individual Data Points (Jitter)')
plt.xlabel('Region')
plt.ylabel('Spending ($)')
plt.show()
# Out:
# /tmp/ipython-input-281618188.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='Spending', data=df, palette='GnBu_r')

# %%
sns.countplot(data=housing_data, x='Type');

# %%
plt.figure(figsize=(20, 12))
sns.countplot(data=housing_data, x='Type', hue='Price' );

# %%
sns.lineplot(data=housing_data, x='Rooms', y='Price');

# %%
housing_data.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %%
sns.lineplot(data=housing_data, x='Suburb', y='Price');
plt.xticks(rotation=90);

# %%
sns.lineplot(data=housing_data, x='Date', y='Price',hue='Price' );
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-271289682.py in <cell line: 0>()
# ----> 1 sns.lineplot(data=housing_data, x='Date', y='Price',hue='Price' );
#
# /usr/local/lib/python3.12/dist-packages/seaborn/relational.py in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     513     kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
#     514
# --> 515     p.plot(ax, kwargs)
#     516     return ax
#     517
#
# /usr/local/lib/python3.12/dist-packages/seaborn/relational.py in plot(self, ax, kws)
#     293                 # but that fails on a corner case with older pandas.
#     294                 sub_data = (
# --> 295                     grouped
# ...

# %%
flights_data= sns.load_dataset('flights')
flights_data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flights_data, x='month', y='passengers', color='green');

# %%
sns.lineplot(data=flights_data, x='month', y='passengers', color='green', ci=False);
# Out:
# /tmp/ipython-input-3350213897.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=flights_data, x='month', y='passengers', color='green', ci=False);

# %%
sns.lineplot(data=flights_data, x='month', y='passengers',  ci=False, hue='year');
# Out:
# /tmp/ipython-input-2430459037.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=flights_data, x='month', y='passengers',  ci=False, hue='year');

# %%
sns.lineplot(data=flights_data, x='month', y='passengers',  hue='year');

# %%
mri_dataset =sns.load_dataset('fmri')
mri_dataset
# Out:
#      subject  timepoint event    region  signal
# 0        s13         18  stim  parietal  -0.018
# 1         s5         14  stim  parietal  -0.081
# 2        s12         18  stim  parietal  -0.081
# 3        s11         18  stim  parietal  -0.046
# 4        s10         18  stim  parietal  -0.038
# ...      ...        ...   ...       ...     ...
# 1059      s0          8   cue   frontal   0.018
# 1060     s13          7   cue   frontal  -0.029
# 1061     s12          7   cue   frontal  -0.005
# 1062     s11          7   cue   frontal  -0.025
# 1063      s0          0   cue  parietal  -0.007
#
# [1064 rows x 5 columns]

# %%
mri_dataset.describe()
# Out:
#        timepoint   signal
# count   1064.000 1064.000
# mean       9.000    0.004
# std        5.480    0.094
# min        0.000   -0.255
# 25%        4.000   -0.046
# 50%        9.000   -0.014
# 75%       14.000    0.024
# max       18.000    0.565

# %%
mri_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
mri_dataset.isnull().sum()
# Out:
# subject      0
# timepoint    0
# event        0
# region       0
# signal       0
# dtype: int64

# %%
mri_dataset.head()
# Out:
#   subject  timepoint event    region  signal
# 0     s13         18  stim  parietal  -0.018
# 1      s5         14  stim  parietal  -0.081
# 2     s12         18  stim  parietal  -0.081
# 3     s11         18  stim  parietal  -0.046
# 4     s10         18  stim  parietal  -0.038

# %%
mri_dataset.tail()
# Out:
#      subject  timepoint event    region  signal
# 1059      s0          8   cue   frontal   0.018
# 1060     s13          7   cue   frontal  -0.029
# 1061     s12          7   cue   frontal  -0.005
# 1062     s11          7   cue   frontal  -0.025
# 1063      s0          0   cue  parietal  -0.007

# %%
mri_dataset.shape
# Out:
# (1064, 5)

# %%
mri_dataset.ndim
# Out:
# 2

# %%
sns.lineplot(data=mri_dataset, x='timepoint', y='signal', hue='event', style='region');

# %%
sns.lineplot(data=mri_dataset, x='timepoint', y='signal', hue='event', style='region', ci=False);
# Out:
# /tmp/ipython-input-3652611533.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=mri_dataset, x='timepoint', y='signal', hue='event', style='region', ci=False);

# %%
sns.lineplot(data=mri_dataset, x='timepoint', y='signal', hue='event', style='region', ci=False, markers=True);
# Out:
# /tmp/ipython-input-799112813.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=mri_dataset, x='timepoint', y='signal', hue='event', style='region', ci=False, markers=True);

# %%
sns.histplot(housing_data, x='Distance', stat='density');
plt.show()

sns.boxplot(housing_data, x='Distance');

# %%
sns.displot(housing_data,x='Landsize', kind='kde')
plt.show()

sns.boxplot(housing_data, x='Landsize');
plt.show()

# %%
housing_data.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %%
housing_data[housing_data['Landsize'] > 60000]
# Out:
#              Suburb  Rooms Type    SellerG       Date  Distance  Postcode  \
# 23908        Silvan      3    h  Harcourts 2017-05-27    34.600  3795.000
# 25090  Balwyn North      3    h        Kay 2016-08-28     9.200  3104.000
#
#        Bedroom  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 23908    3.000     2.000 2.000 76000.000           NaN        NaN
# 25090    3.000     1.000 2.000 75100.000           NaN        NaN
#
#                   Regionname  Propertycount    Price
# 23908       Eastern Victoria            457  1085000
# 25090  Southern Metropolitan           7809  2000000

# %%
housing_data.loc[housing_data['Rooms'] >7 ].shape
# Out:
# (23, 16)

# %%
housing_data.loc[housing_data['Rooms'] >7 ]
# Out:
#                    Suburb  Rooms Type        SellerG       Date  Distance  \
# 897     Templestowe Lower      8    h          Barry 2016-06-04    13.800
# 2013            Ashburton      8    h  hockingstuart 2016-09-10    11.000
# 2187       Oakleigh South      9    h            Ray 2016-09-10    14.700
# 2557            Parkville      8    u          Kelly 2016-12-10     2.600
# 4598               Coburg      8    u          Peter 2017-03-04     7.800
# 5481              Newport      8    h           Greg 2017-10-07     6.200
# 6038           Camberwell      8    h           Ross 2017-07-08     7.700
# 7989               Melton     12    h  PRDNationwide 2017-11-11    31.700
# 10460       Brighton East      8    h         Buxton 2017-05-13    10.700
# 11253             Burwood      8    h             RW 2017-10-14    10.400
# 11687         Westmeadows      8    h      Stockdale 2017-10-14    16.500
# 11758            Bundoora     10    h            Ray 2017-07-15    12.100
# ...

# %%
housing_data.loc[housing_data['Rooms'] >1, 'Type' ].value_counts()
# Out:
# Type
# h    18314
# u     4789
# t     2809
# Name: count, dtype: int64

# %%
sns.countplot(data=housing_data, x='Type', hue='Rooms');
plt.show()
print("\n\n\n")
sns.countplot(data=housing_data, x='Regionname', hue='Regionname');
plt.show()

# %%
sns.countplot(data=housing_data, x='Regionname', hue='Regionname');
plt.xticks(rotation=90);
plt.show()

# %%
sns.scatterplot(data=housing_data, x='BuildingArea', y='Price');

# %%
print(housing_data.columns)
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %%
automobile_data = pd.read_csv('Automobile.csv')
automobile_data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front      88.600  ...
# 1             two  convertible          rwd           front      88.600  ...
# 2             two    hatchback          rwd           front      94.500  ...
# 3            four        sedan          fwd           front      99.800  ...
# 4            four        sedan          4wd           front      99.400  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
automobile_data.shape
# Out:
# (201, 26)

# %%
automobile_data.describe()
# Out:
#        symboling  normalized_losses  wheel_base  length   width  height  \
# count    201.000            201.000     201.000 201.000 201.000 201.000
# mean       0.841            125.189      98.797 174.201  65.889  53.767
# std        1.255             33.573       6.066  12.322   2.101   2.448
# min       -2.000             65.000      86.600 141.100  60.300  47.800
# 25%        0.000            101.000      94.500 166.800  64.100  52.000
# 50%        1.000            122.000      97.000 173.200  65.500  54.100
# 75%        2.000            150.000     102.400 183.500  66.600  55.500
# max        3.000            256.000     120.900 208.100  72.000  59.800
#
#        curb_weight  engine_size    bore  stroke  compression_ratio  \
# count      201.000      201.000 201.000 201.000            201.000
# mean      2555.667      126.876   3.330   3.262             10.164
# std        517.297       41.547   0.268   0.318              4.005
# ...

# %%
sns.scatterplot(automobile_data, x='horsepower', y='price');

# %%
sns.scatterplot(automobile_data, x='body_style', y='price');

# %%
sns.scatterplot(automobile_data, x='make', y='city_mpg', hue='price');
plt.xticks(rotation=90);

# %%
automobile_data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
sns.countplot(data=automobile_data, x='make', hue='body_style');
plt.xticks(rotation=90);

# %%
# sns.FacetGrid(automobile_data, col='body_style').map(sns.histplot, 'price');
plt.figure(figsize=(60,50))
sns.countplot(data=automobile_data, x='price', hue='make');
plt.xscale('linear')
plt.xticks(rotation=90);
